# %% [markdown]
# <a href="https://colab.research.google.com/github/woojin9605/Practice/blob/main/ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T

import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd

manualseed = 999 # random seed 고정
random.seed(manualseed) # for numpy
torch.manual_seed(manualseed) # for torch

dtype = torch.float32
device = torch.device('cuda')

Num_Train = 45000
lr = 0.1
num_worker = 4
batch_size = 128
batch_size_test = 100

transform_train = T.Compose([
                       T.RandomCrop(32,padding=4),
                       T.RandomHorizontalFlip(),
                       T.ToTensor(),
                       T.Normalize((0.4914, 0.4822, 0.4465),(0.2470, 0.2435, 0.2616))
])
transform_test = T.Compose([
                       T.ToTensor(),
                       T.Normalize((0.4914, 0.4822, 0.4465),(0.2470, 0.2435, 0.2616))
])

cifar10_train = dset.CIFAR10(root='./CIFAR10',train=True,
                             download=True,transform=transform_train)
loader_train = DataLoader(cifar10_train,batch_size=batch_size,
                          sampler=sampler.SubsetRandomSampler(range(Num_Train)))

cifar10_val = dset.CIFAR10(root='./CIFAR10',train=True,
                           download=True,transform=transform_test)
loader_val = DataLoader(cifar10_val,batch_size=batch_size,
                          sampler=sampler.SubsetRandomSampler(range(Num_Train,50000)))

cifar10_test = dset.CIFAR10(root='./CIFAR10',train=False,
                           download=True,transform=transform_test)
loader_test = DataLoader(cifar10_test, batch_size=batch_size_test)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./CIFAR10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./CIFAR10/cifar-10-python.tar.gz to ./CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Make ResNet Model for CIFAR-10

# %%
class downsample_pad(nn.Module):
  def __init__(self,in_channels,out_channels,stride):
    super().__init__()
    self.maxpool = nn.MaxPool2d(1,stride)
    self.pad = nn.ConstantPad3d((0,0,0,0,0,out_channels-in_channels),0)

  def forward(self,x):
    out = self.maxpool(x)
    out = self.pad(out)
    return out

class ResBlock(nn.Module):
  def __init__(self,in_channels,out_channels,stride):
    super().__init__()
    self.stride = stride
    self.conv1 = nn.Conv2d(in_channels,out_channels,3,padding=1,bias=False,stride=stride)
    self.bn1 = nn.BatchNorm2d(out_channels)
    self.relu = nn.ReLU(True)
    self.conv2 = nn.Conv2d(out_channels,out_channels,3,padding=1,bias=False,stride=1)
    self.bn2 = nn.BatchNorm2d(out_channels)
    self.downsampad = downsample_pad(in_channels,out_channels,stride)
    
  def forward(self,x):
    if self.stride == 2:
      shortcut = self.downsampad(x)
    else:
      shortcut = x
    out = self.conv1(x)
    out = self.bn1(out)
    out = self.relu(out)
    out = self.conv2(out)
    out = self.bn2(out)
    out += shortcut
    out = self.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self,n,num_classes=10):
    super().__init__()
    self.n = n
    self.conv1 = nn.Conv2d(3,16,3,padding=1,bias=False) # N*16*32*32
    self.bn1 = nn.BatchNorm2d(16)
    self.relu = nn.ReLU(True)

    self.layers_2n_32 = self.make_layers(16,16,1)# N*16*32*32
    self.layers_2n_16 = self.make_layers(16,32,2)# N*32*16*16
    self.layers_2n_8 = self.make_layers(32,64,2)# N*64*8*8

    self.gloavg_pool = nn.AvgPool2d(8)# N*64*1*1
    self.flatten = nn.Flatten()
    self.fc_out = nn.Linear(64*1*1,num_classes)# N*10

    for m in self.modules(): # weight initialization
      classname = m.__class__.__name__
      if classname.find('Conv') != -1:
        nn.init.kaiming_normal_(m.weight,mode='fan_out',nonlinearity='relu')
      elif classname.find('BatchNorm') != -1:
        nn.init.constant_(m.weight,1)
        nn.init.constant_(m.bias,0)
        
  def make_layers(self,in_channels,out_channels,stride):
    layers = []
    layers += [ResBlock(in_channels,out_channels,stride=stride)]
    for _ in range(self.n-1):
      layers += [ResBlock(out_channels,out_channels,stride=1)]
    return nn.Sequential(*layers)

  def forward(self, x):
    x = self.conv1(x)
    x = self.bn1(x)
    x = self.relu(x)

    x = self.layers_2n_32(x)
    x = self.layers_2n_16(x)
    x = self.layers_2n_8(x)

    x = self.gloavg_pool(x)
    x = self.flatten(x)
    x = self.fc_out(x)
    return x

# %% [markdown]
# Make Plain Model for CIFAR-10

# %%
class Block(nn.Module):
  def __init__(self,in_channels,out_channels,stride):
    super().__init__()
    self.stride = stride
    self.conv1 = nn.Conv2d(in_channels,out_channels,3,padding=1,bias=False,stride=stride)
    self.bn1 = nn.BatchNorm2d(out_channels)
    self.relu = nn.ReLU(True)
    self.conv2 = nn.Conv2d(out_channels,out_channels,3,padding=1,bias=False,stride=1)
    self.bn2 = nn.BatchNorm2d(out_channels)
    
  def forward(self,x):
    out = self.conv1(x)
    out = self.bn1(out)
    out = self.relu(out)
    out = self.conv2(out)
    out = self.bn2(out)
    out = self.relu(out)
    return out

class PlainNet(nn.Module):
  def __init__(self,n,num_classes=10):
    super().__init__()
    self.n = n
    self.conv1 = nn.Conv2d(3,16,3,padding=1,bias=False) # N*16*32*32
    self.bn1 = nn.BatchNorm2d(16)
    self.relu = nn.ReLU(True)

    self.layers_2n_32 = self.make_layers(16,16,1)# N*16*32*32
    self.layers_2n_16 = self.make_layers(16,32,2)# N*32*16*16
    self.layers_2n_8 = self.make_layers(32,64,2)# N*64*8*8

    self.gloavg_pool = nn.AvgPool2d(8)# N*64*1*1
    self.flatten = nn.Flatten()
    self.fc_out = nn.Linear(64*1*1,num_classes)# N*10

    for m in self.modules(): # weight initialization
      classname = m.__class__.__name__
      if classname.find('Conv') != -1:
        nn.init.kaiming_normal_(m.weight,mode='fan_out',nonlinearity='relu')
      elif classname.find('BatchNorm') != -1:
        nn.init.constant_(m.weight,1)
        nn.init.constant_(m.bias,0)
        
  def make_layers(self,in_channels,out_channels,stride):
    layers = []
    layers += [Block(in_channels,out_channels,stride=stride)]
    for _ in range(self.n-1):
      layers += [Block(out_channels,out_channels,stride=1)]
    return nn.Sequential(*layers)

  def forward(self, x):
    x = self.conv1(x)
    x = self.bn1(x)
    x = self.relu(x)

    x = self.layers_2n_32(x)
    x = self.layers_2n_16(x)
    x = self.layers_2n_8(x)

    x = self.gloavg_pool(x)
    x = self.flatten(x)
    x = self.fc_out(x)
    return x

# %% [markdown]
# Start Training

# %%
net = PlainNet(3).to(device) # can choose resnet or plainnet and n=3,5,7,9...
num_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print('The number of parameters of model is', num_params)
#print(net)

optimizer = optim.SGD(net.parameters(),lr=lr,momentum=0.9,weight_decay=1e-4)
schedule = [32000,48000]
lr_sche = optim.lr_scheduler.MultiStepLR(optimizer, milestones=schedule, gamma=0.1)

TrainError_log = []
TestError_log = []
total_iter = 0
end_iter = 64000
epochs = 0
print_every = 4000

def train(model, total_iter):
  model.train()
  num_correct = 0
  num_samples = 0
  for t,(x,y) in enumerate(loader_train):
    total_iter += 1
    x = x.to(device=device, dtype=dtype)
    y = y.to(device=device, dtype=torch.long)

    scores = model(x)
    loss = F.cross_entropy(scores,y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    lr_sche.step()
  return total_iter
  
def check_acc(model,loader,log, test):
  model.eval()
  num_correct = 0
  num_samples = 0

  for (x,y) in loader:
    x = x.to(device=device, dtype=dtype)
    y = y.to(device=device, dtype=torch.long)

    scores = model(x)
    _, predicts = torch.max(scores,dim=1)
    num_correct += torch.sum(predicts == y)
    num_samples += predicts.size(0)

  acc = float(num_correct) / num_samples
  error = 100*(1-acc)
  log.append(error)
  if test:
    print('(TestError) correct : %d / %d, error (%.2f)' % (num_correct,num_samples,error))
  else:
    print('(TrainError) correct : %d / %d, error (%.2f)' % (num_correct,num_samples,error))
# Out:
# The number of parameters of model is 269722

# %%
while True:
  epochs += 1
  total_iter = train(net,total_iter)
  check_acc(net, loader_train, TrainError_log, test=False)
  check_acc(net, loader_test, TestError_log, test=True)
  print('iter : %d / %d , epochs : %d' % (total_iter, end_iter, epochs))

  if total_iter >= end_iter:
    dataframe1 = pd.DataFrame(TrainError_log)
    dataframe1.to_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_20_trainerr.csv',header=False,index=False)
    dataframe2 = pd.DataFrame(TestError_log)
    dataframe2.to_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_20_testerr.csv',header=False,index=False)
    print('training finished')
    break
# Out:
# (TrainError) correct : 17648 / 45000, error (60.78)
# (TestError) correct : 3954 / 10000, error (60.46)
# iter : 352 / 64000 , epochs : 1
# (TrainError) correct : 21323 / 45000, error (52.62)
# (TestError) correct : 4836 / 10000, error (51.64)
# iter : 704 / 64000 , epochs : 2
# (TrainError) correct : 28293 / 45000, error (37.13)
# (TestError) correct : 6258 / 10000, error (37.42)
# iter : 1056 / 64000 , epochs : 3
# (TrainError) correct : 30049 / 45000, error (33.22)
# (TestError) correct : 6687 / 10000, error (33.13)
# iter : 1408 / 64000 , epochs : 4
# (TrainError) correct : 30537 / 45000, error (32.14)
# (TestError) correct : 6658 / 10000, error (33.42)
# iter : 1760 / 64000 , epochs : 5
# (TrainError) correct : 30284 / 45000, error (32.70)
# (TestError) correct : 6677 / 10000, error (33.23)
# iter : 2112 / 64000 , epochs : 6
# (TrainError) correct : 32934 / 45000, error (26.81)
# (TestError) correct : 7264 / 10000, error (27.36)
# iter : 2464 / 64000 , epochs : 7
# (TrainError) correct : 34740 / 45000, error (22.80)
# (TestError) correct : 7608 / 10000, error (23.92)
# iter : 2816 / 64000 , epochs : 8
# (TrainError) correct : 34975 / 45000, error (22.28)
# (TestError) correct : 7717 / 10000, error (22.83)
# iter : 3168 / 64000 , epochs : 9
# (TrainError) correct : 34304 / 45000, error (23.77)
# (TestError) correct : 7399 / 10000, error (26.01)
# iter : 3520 / 64000 , epochs : 10
# (TrainError) correct : 35039 / 45000, error (22.14)
# (TestError) correct : 7685 / 10000, error (23.15)
# iter : 3872 / 64000 , epochs : 11
# (TrainError) correct : 34049 / 45000, error (24.34)
# (TestError) correct : 7373 / 10000, error (26.27)
# iter : 4224 / 64000 , epochs : 12
# (TrainError) correct : 35147 / 45000, error (21.90)
# (TestError) correct : 7633 / 10000, error (23.67)
# iter : 4576 / 64000 , epochs : 13
# (TrainError) correct : 34893 / 45000, error (22.46)
# (TestError) correct : 7586 / 10000, error (24.14)
# iter : 4928 / 64000 , epochs : 14
# (TrainError) correct : 36170 / 45000, error (19.62)
# (TestError) correct : 7895 / 10000, error (21.05)
# iter : 5280 / 64000 , epochs : 15
# (TrainError) correct : 35961 / 45000, error (20.09)
# (TestError) correct : 7674 / 10000, error (23.26)
# iter : 5632 / 64000 , epochs : 16
# (TrainError) correct : 36750 / 45000, error (18.33)
# (TestError) correct : 7957 / 10000, error (20.43)
# iter : 5984 / 64000 , epochs : 17
# (TrainError) correct : 36355 / 45000, error (19.21)
# (TestError) correct : 7894 / 10000, error (21.06)
# iter : 6336 / 64000 , epochs : 18
# (TrainError) correct : 35742 / 45000, error (20.57)
# (TestError) correct : 7717 / 10000, error (22.83)
# iter : 6688 / 64000 , epochs : 19
# (TrainError) correct : 35967 / 45000, error (20.07)
# (TestError) correct : 7733 / 10000, error (22.67)
# iter : 7040 / 64000 , epochs : 20
# (TrainError) correct : 37515 / 45000, error (16.63)
# (TestError) correct : 8130 / 10000, error (18.70)
# iter : 7392 / 64000 , epochs : 21
# (TrainError) correct : 36707 / 45000, error (18.43)
# (TestError) correct : 7900 / 10000, error (21.00)
# iter : 7744 / 64000 , epochs : 22
# (TrainError) correct : 36559 / 45000, error (18.76)
# (TestError) correct : 7913 / 10000, error (20.87)
# iter : 8096 / 64000 , epochs : 23
# (TrainError) correct : 38104 / 45000, error (15.32)
# (TestError) correct : 8152 / 10000, error (18.48)
# iter : 8448 / 64000 , epochs : 24
# (TrainError) correct : 38227 / 45000, error (15.05)
# (TestError) correct : 8209 / 10000, error (17.91)
# iter : 8800 / 64000 , epochs : 25
# (TrainError) correct : 36142 / 45000, error (19.68)
# (TestError) correct : 7769 / 10000, error (22.31)
# iter : 9152 / 64000 , epochs : 26
# (TrainError) correct : 38295 / 45000, error (14.90)
# (TestError) correct : 8227 / 10000, error (17.73)
# iter : 9504 / 64000 , epochs : 27
# (TrainError) correct : 38567 / 45000, error (14.30)
# (TestError) correct : 8217 / 10000, error (17.83)
# iter : 9856 / 64000 , epochs : 28
# (TrainError) correct : 38259 / 45000, error (14.98)
# (TestError) correct : 8214 / 10000, error (17.86)
# iter : 10208 / 64000 , epochs : 29
# (TrainError) correct : 37156 / 45000, error (17.43)
# (TestError) correct : 8024 / 10000, error (19.76)
# iter : 10560 / 64000 , epochs : 30
# (TrainError) correct : 33864 / 45000, error (24.75)
# (TestError) correct : 7179 / 10000, error (28.21)
# iter : 10912 / 64000 , epochs : 31
# (TrainError) correct : 38108 / 45000, error (15.32)
# (TestError) correct : 8181 / 10000, error (18.19)
# iter : 11264 / 64000 , epochs : 32
# (TrainError) correct : 35945 / 45000, error (20.12)
# (TestError) correct : 7783 / 10000, error (22.17)
# iter : 11616 / 64000 , epochs : 33
# (TrainError) correct : 38313 / 45000, error (14.86)
# (TestError) correct : 8260 / 10000, error (17.40)
# iter : 11968 / 64000 , epochs : 34
# (TrainError) correct : 35462 / 45000, error (21.20)
# (TestError) correct : 7732 / 10000, error (22.68)
# iter : 12320 / 64000 , epochs : 35
# (TrainError) correct : 38653 / 45000, error (14.10)
# (TestError) correct : 8233 / 10000, error (17.67)
# iter : 12672 / 64000 , epochs : 36
# (TrainError) correct : 37228 / 45000, error (17.27)
# (TestError) correct : 7998 / 10000, error (20.02)
# iter : 13024 / 64000 , epochs : 37
# (TrainError) correct : 36913 / 45000, error (17.97)
# (TestError) correct : 7927 / 10000, error (20.73)
# iter : 13376 / 64000 , epochs : 38
# (TrainError) correct : 39009 / 45000, error (13.31)
# (TestError) correct : 8316 / 10000, error (16.84)
# iter : 13728 / 64000 , epochs : 39
# (TrainError) correct : 34941 / 45000, error (22.35)
# (TestError) correct : 7504 / 10000, error (24.96)
# iter : 14080 / 64000 , epochs : 40
# (TrainError) correct : 38156 / 45000, error (15.21)
# (TestError) correct : 8087 / 10000, error (19.13)
# iter : 14432 / 64000 , epochs : 41
# (TrainError) correct : 36263 / 45000, error (19.42)
# (TestError) correct : 7754 / 10000, error (22.46)
# iter : 14784 / 64000 , epochs : 42
# (TrainError) correct : 38845 / 45000, error (13.68)
# (TestError) correct : 8268 / 10000, error (17.32)
# iter : 15136 / 64000 , epochs : 43
# (TrainError) correct : 38831 / 45000, error (13.71)
# (TestError) correct : 8304 / 10000, error (16.96)
# iter : 15488 / 64000 , epochs : 44
# (TrainError) correct : 36590 / 45000, error (18.69)
# (TestError) correct : 7725 / 10000, error (22.75)
# iter : 15840 / 64000 , epochs : 45
# (TrainError) correct : 39820 / 45000, error (11.51)
# (TestError) correct : 8464 / 10000, error (15.36)
# iter : 16192 / 64000 , epochs : 46
# (TrainError) correct : 38948 / 45000, error (13.45)
# (TestError) correct : 8262 / 10000, error (17.38)
# iter : 16544 / 64000 , epochs : 47
# (TrainError) correct : 38888 / 45000, error (13.58)
# (TestError) correct : 8233 / 10000, error (17.67)
# iter : 16896 / 64000 , epochs : 48
# (TrainError) correct : 39631 / 45000, error (11.93)
# (TestError) correct : 8406 / 10000, error (15.94)
# iter : 17248 / 64000 , epochs : 49
# (TrainError) correct : 38816 / 45000, error (13.74)
# (TestError) correct : 8321 / 10000, error (16.79)
# iter : 17600 / 64000 , epochs : 50
# (TrainError) correct : 38282 / 45000, error (14.93)
# (TestError) correct : 8220 / 10000, error (17.80)
# iter : 17952 / 64000 , epochs : 51
# (TrainError) correct : 39734 / 45000, error (11.70)
# (TestError) correct : 8375 / 10000, error (16.25)
# iter : 18304 / 64000 , epochs : 52
# (TrainError) correct : 38060 / 45000, error (15.42)
# (TestError) correct : 8008 / 10000, error (19.92)
# iter : 18656 / 64000 , epochs : 53
# (TrainError) correct : 39252 / 45000, error (12.77)
# (TestError) correct : 8347 / 10000, error (16.53)
# iter : 19008 / 64000 , epochs : 54
# (TrainError) correct : 38961 / 45000, error (13.42)
# (TestError) correct : 8288 / 10000, error (17.12)
# iter : 19360 / 64000 , epochs : 55
# (TrainError) correct : 39874 / 45000, error (11.39)
# (TestError) correct : 8461 / 10000, error (15.39)
# iter : 19712 / 64000 , epochs : 56
# (TrainError) correct : 38162 / 45000, error (15.20)
# (TestError) correct : 8123 / 10000, error (18.77)
# iter : 20064 / 64000 , epochs : 57
# (TrainError) correct : 39266 / 45000, error (12.74)
# (TestError) correct : 8296 / 10000, error (17.04)
# iter : 20416 / 64000 , epochs : 58
# (TrainError) correct : 40459 / 45000, error (10.09)
# (TestError) correct : 8543 / 10000, error (14.57)
# iter : 20768 / 64000 , epochs : 59
# (TrainError) correct : 39932 / 45000, error (11.26)
# (TestError) correct : 8483 / 10000, error (15.17)
# iter : 21120 / 64000 , epochs : 60
# (TrainError) correct : 38310 / 45000, error (14.87)
# (TestError) correct : 8156 / 10000, error (18.44)
# iter : 21472 / 64000 , epochs : 61
# (TrainError) correct : 39565 / 45000, error (12.08)
# (TestError) correct : 8362 / 10000, error (16.38)
# iter : 21824 / 64000 , epochs : 62
# (TrainError) correct : 39830 / 45000, error (11.49)
# (TestError) correct : 8429 / 10000, error (15.71)
# iter : 22176 / 64000 , epochs : 63
# (TrainError) correct : 39983 / 45000, error (11.15)
# (TestError) correct : 8468 / 10000, error (15.32)
# iter : 22528 / 64000 , epochs : 64
# (TrainError) correct : 38873 / 45000, error (13.62)
# (TestError) correct : 8195 / 10000, error (18.05)
# iter : 22880 / 64000 , epochs : 65
# (TrainError) correct : 39543 / 45000, error (12.13)
# (TestError) correct : 8456 / 10000, error (15.44)
# iter : 23232 / 64000 , epochs : 66
# (TrainError) correct : 39458 / 45000, error (12.32)
# (TestError) correct : 8361 / 10000, error (16.39)
# iter : 23584 / 64000 , epochs : 67
# (TrainError) correct : 39398 / 45000, error (12.45)
# (TestError) correct : 8364 / 10000, error (16.36)
# iter : 23936 / 64000 , epochs : 68
# (TrainError) correct : 40415 / 45000, error (10.19)
# (TestError) correct : 8569 / 10000, error (14.31)
# iter : 24288 / 64000 , epochs : 69
# (TrainError) correct : 38935 / 45000, error (13.48)
# (TestError) correct : 8330 / 10000, error (16.70)
# iter : 24640 / 64000 , epochs : 70
# (TrainError) correct : 40241 / 45000, error (10.58)
# (TestError) correct : 8493 / 10000, error (15.07)
# iter : 24992 / 64000 , epochs : 71
# (TrainError) correct : 39532 / 45000, error (12.15)
# (TestError) correct : 8387 / 10000, error (16.13)
# iter : 25344 / 64000 , epochs : 72
# (TrainError) correct : 39451 / 45000, error (12.33)
# (TestError) correct : 8310 / 10000, error (16.90)
# iter : 25696 / 64000 , epochs : 73
# (TrainError) correct : 39691 / 45000, error (11.80)
# (TestError) correct : 8393 / 10000, error (16.07)
# iter : 26048 / 64000 , epochs : 74
# (TrainError) correct : 40043 / 45000, error (11.02)
# (TestError) correct : 8418 / 10000, error (15.82)
# iter : 26400 / 64000 , epochs : 75
# (TrainError) correct : 38568 / 45000, error (14.29)
# (TestError) correct : 8196 / 10000, error (18.04)
# iter : 26752 / 64000 , epochs : 76
# (TrainError) correct : 39208 / 45000, error (12.87)
# (TestError) correct : 8254 / 10000, error (17.46)
# iter : 27104 / 64000 , epochs : 77
# (TrainError) correct : 39702 / 45000, error (11.77)
# (TestError) correct : 8393 / 10000, error (16.07)
# iter : 27456 / 64000 , epochs : 78
# (TrainError) correct : 39115 / 45000, error (13.08)
# (TestError) correct : 8283 / 10000, error (17.17)
# iter : 27808 / 64000 , epochs : 79
# (TrainError) correct : 38669 / 45000, error (14.07)
# (TestError) correct : 8168 / 10000, error (18.32)
# iter : 28160 / 64000 , epochs : 80
# (TrainError) correct : 39254 / 45000, error (12.77)
# (TestError) correct : 8291 / 10000, error (17.09)
# iter : 28512 / 64000 , epochs : 81
# (TrainError) correct : 39170 / 45000, error (12.96)
# (TestError) correct : 8290 / 10000, error (17.10)
# iter : 28864 / 64000 , epochs : 82
# (TrainError) correct : 39968 / 45000, error (11.18)
# (TestError) correct : 8447 / 10000, error (15.53)
# iter : 29216 / 64000 , epochs : 83
# (TrainError) correct : 39888 / 45000, error (11.36)
# (TestError) correct : 8493 / 10000, error (15.07)
# iter : 29568 / 64000 , epochs : 84
# (TrainError) correct : 39828 / 45000, error (11.49)
# (TestError) correct : 8445 / 10000, error (15.55)
# iter : 29920 / 64000 , epochs : 85
# (TrainError) correct : 38414 / 45000, error (14.64)
# (TestError) correct : 8176 / 10000, error (18.24)
# iter : 30272 / 64000 , epochs : 86
# (TrainError) correct : 39397 / 45000, error (12.45)
# (TestError) correct : 8326 / 10000, error (16.74)
# iter : 30624 / 64000 , epochs : 87
# (TrainError) correct : 38297 / 45000, error (14.90)
# (TestError) correct : 8183 / 10000, error (18.17)
# iter : 30976 / 64000 , epochs : 88
# (TrainError) correct : 40510 / 45000, error (9.98)
# (TestError) correct : 8516 / 10000, error (14.84)
# iter : 31328 / 64000 , epochs : 89
# (TrainError) correct : 39356 / 45000, error (12.54)
# (TestError) correct : 8295 / 10000, error (17.05)
# iter : 31680 / 64000 , epochs : 90
# (TrainError) correct : 41946 / 45000, error (6.79)
# (TestError) correct : 8795 / 10000, error (12.05)
# iter : 32032 / 64000 , epochs : 91
# (TrainError) correct : 42953 / 45000, error (4.55)
# (TestError) correct : 8931 / 10000, error (10.69)
# iter : 32384 / 64000 , epochs : 92
# (TrainError) correct : 43143 / 45000, error (4.13)
# (TestError) correct : 8954 / 10000, error (10.46)
# iter : 32736 / 64000 , epochs : 93
# (TrainError) correct : 43364 / 45000, error (3.64)
# (TestError) correct : 8983 / 10000, error (10.17)
# iter : 33088 / 64000 , epochs : 94
# (TrainError) correct : 43391 / 45000, error (3.58)
# (TestError) correct : 8985 / 10000, error (10.15)
# iter : 33440 / 64000 , epochs : 95
# (TrainError) correct : 43470 / 45000, error (3.40)
# (TestError) correct : 8979 / 10000, error (10.21)
# iter : 33792 / 64000 , epochs : 96
# (TrainError) correct : 43583 / 45000, error (3.15)
# (TestError) correct : 8978 / 10000, error (10.22)
# iter : 34144 / 64000 , epochs : 97
# (TrainError) correct : 43620 / 45000, error (3.07)
# (TestError) correct : 8987 / 10000, error (10.13)
# iter : 34496 / 64000 , epochs : 98
# (TrainError) correct : 43623 / 45000, error (3.06)
# (TestError) correct : 8981 / 10000, error (10.19)
# iter : 34848 / 64000 , epochs : 99
# (TrainError) correct : 43664 / 45000, error (2.97)
# (TestError) correct : 8970 / 10000, error (10.30)
# iter : 35200 / 64000 , epochs : 100
# (TrainError) correct : 43744 / 45000, error (2.79)
# (TestError) correct : 8971 / 10000, error (10.29)
# iter : 35552 / 64000 , epochs : 101
# (TrainError) correct : 43814 / 45000, error (2.64)
# (TestError) correct : 8997 / 10000, error (10.03)
# iter : 35904 / 64000 , epochs : 102
# (TrainError) correct : 43830 / 45000, error (2.60)
# (TestError) correct : 8970 / 10000, error (10.30)
# iter : 36256 / 64000 , epochs : 103
# (TrainError) correct : 43877 / 45000, error (2.50)
# (TestError) correct : 8992 / 10000, error (10.08)
# iter : 36608 / 64000 , epochs : 104
# (TrainError) correct : 43873 / 45000, error (2.50)
# (TestError) correct : 8973 / 10000, error (10.27)
# iter : 36960 / 64000 , epochs : 105
# (TrainError) correct : 43913 / 45000, error (2.42)
# (TestError) correct : 8997 / 10000, error (10.03)
# iter : 37312 / 64000 , epochs : 106
# (TrainError) correct : 43911 / 45000, error (2.42)
# (TestError) correct : 8991 / 10000, error (10.09)
# iter : 37664 / 64000 , epochs : 107
# (TrainError) correct : 43999 / 45000, error (2.22)
# (TestError) correct : 8986 / 10000, error (10.14)
# iter : 38016 / 64000 , epochs : 108
# (TrainError) correct : 43964 / 45000, error (2.30)
# (TestError) correct : 8986 / 10000, error (10.14)
# iter : 38368 / 64000 , epochs : 109
# (TrainError) correct : 44005 / 45000, error (2.21)
# (TestError) correct : 9005 / 10000, error (9.95)
# iter : 38720 / 64000 , epochs : 110
# (TrainError) correct : 44093 / 45000, error (2.02)
# (TestError) correct : 8986 / 10000, error (10.14)
# iter : 39072 / 64000 , epochs : 111
# (TrainError) correct : 44062 / 45000, error (2.08)
# (TestError) correct : 8989 / 10000, error (10.11)
# iter : 39424 / 64000 , epochs : 112
# (TrainError) correct : 44104 / 45000, error (1.99)
# (TestError) correct : 8988 / 10000, error (10.12)
# iter : 39776 / 64000 , epochs : 113
# (TrainError) correct : 44093 / 45000, error (2.02)
# (TestError) correct : 8998 / 10000, error (10.02)
# iter : 40128 / 64000 , epochs : 114
# (TrainError) correct : 44166 / 45000, error (1.85)
# (TestError) correct : 8999 / 10000, error (10.01)
# iter : 40480 / 64000 , epochs : 115
# (TrainError) correct : 44179 / 45000, error (1.82)
# (TestError) correct : 8988 / 10000, error (10.12)
# iter : 40832 / 64000 , epochs : 116
# (TrainError) correct : 44139 / 45000, error (1.91)
# (TestError) correct : 8979 / 10000, error (10.21)
# iter : 41184 / 64000 , epochs : 117
# (TrainError) correct : 43999 / 45000, error (2.22)
# (TestError) correct : 8978 / 10000, error (10.22)
# iter : 41536 / 64000 , epochs : 118
# (TrainError) correct : 44197 / 45000, error (1.78)
# (TestError) correct : 8999 / 10000, error (10.01)
# iter : 41888 / 64000 , epochs : 119
# (TrainError) correct : 44182 / 45000, error (1.82)
# (TestError) correct : 8963 / 10000, error (10.37)
# iter : 42240 / 64000 , epochs : 120
# (TrainError) correct : 44292 / 45000, error (1.57)
# (TestError) correct : 8967 / 10000, error (10.33)
# iter : 42592 / 64000 , epochs : 121
# (TrainError) correct : 44234 / 45000, error (1.70)
# (TestError) correct : 8980 / 10000, error (10.20)
# iter : 42944 / 64000 , epochs : 122
# (TrainError) correct : 44302 / 45000, error (1.55)
# (TestError) correct : 8972 / 10000, error (10.28)
# iter : 43296 / 64000 , epochs : 123
# (TrainError) correct : 44247 / 45000, error (1.67)
# (TestError) correct : 8955 / 10000, error (10.45)
# iter : 43648 / 64000 , epochs : 124
# (TrainError) correct : 44244 / 45000, error (1.68)
# (TestError) correct : 8957 / 10000, error (10.43)
# iter : 44000 / 64000 , epochs : 125
# (TrainError) correct : 44316 / 45000, error (1.52)
# (TestError) correct : 8987 / 10000, error (10.13)
# iter : 44352 / 64000 , epochs : 126
# (TrainError) correct : 44278 / 45000, error (1.60)
# (TestError) correct : 8991 / 10000, error (10.09)
# iter : 44704 / 64000 , epochs : 127
# (TrainError) correct : 44259 / 45000, error (1.65)
# (TestError) correct : 8967 / 10000, error (10.33)
# iter : 45056 / 64000 , epochs : 128
# (TrainError) correct : 44330 / 45000, error (1.49)
# (TestError) correct : 8954 / 10000, error (10.46)
# iter : 45408 / 64000 , epochs : 129
# (TrainError) correct : 44353 / 45000, error (1.44)
# (TestError) correct : 8965 / 10000, error (10.35)
# iter : 45760 / 64000 , epochs : 130
# (TrainError) correct : 44246 / 45000, error (1.68)
# (TestError) correct : 8932 / 10000, error (10.68)
# iter : 46112 / 64000 , epochs : 131
# (TrainError) correct : 44322 / 45000, error (1.51)
# (TestError) correct : 8956 / 10000, error (10.44)
# iter : 46464 / 64000 , epochs : 132
# (TrainError) correct : 44391 / 45000, error (1.35)
# (TestError) correct : 8986 / 10000, error (10.14)
# iter : 46816 / 64000 , epochs : 133
# (TrainError) correct : 44391 / 45000, error (1.35)
# (TestError) correct : 8985 / 10000, error (10.15)
# iter : 47168 / 64000 , epochs : 134
# (TrainError) correct : 44216 / 45000, error (1.74)
# (TestError) correct : 8946 / 10000, error (10.54)
# iter : 47520 / 64000 , epochs : 135
# (TrainError) correct : 44334 / 45000, error (1.48)
# (TestError) correct : 8975 / 10000, error (10.25)
# iter : 47872 / 64000 , epochs : 136
# (TrainError) correct : 44576 / 45000, error (0.94)
# (TestError) correct : 8992 / 10000, error (10.08)
# iter : 48224 / 64000 , epochs : 137
# (TrainError) correct : 44561 / 45000, error (0.98)
# (TestError) correct : 9004 / 10000, error (9.96)
# iter : 48576 / 64000 , epochs : 138
# (TrainError) correct : 44611 / 45000, error (0.86)
# (TestError) correct : 8990 / 10000, error (10.10)
# iter : 48928 / 64000 , epochs : 139
# (TrainError) correct : 44633 / 45000, error (0.82)
# (TestError) correct : 8990 / 10000, error (10.10)
# iter : 49280 / 64000 , epochs : 140
# (TrainError) correct : 44611 / 45000, error (0.86)
# (TestError) correct : 9000 / 10000, error (10.00)
# iter : 49632 / 64000 , epochs : 141
# (TrainError) correct : 44630 / 45000, error (0.82)
# (TestError) correct : 9003 / 10000, error (9.97)
# iter : 49984 / 64000 , epochs : 142
# (TrainError) correct : 44652 / 45000, error (0.77)
# (TestError) correct : 9006 / 10000, error (9.94)
# iter : 50336 / 64000 , epochs : 143
# (TrainError) correct : 44674 / 45000, error (0.72)
# (TestError) correct : 9021 / 10000, error (9.79)
# iter : 50688 / 64000 , epochs : 144
# (TrainError) correct : 44642 / 45000, error (0.80)
# (TestError) correct : 9014 / 10000, error (9.86)
# iter : 51040 / 64000 , epochs : 145
# (TrainError) correct : 44638 / 45000, error (0.80)
# (TestError) correct : 9011 / 10000, error (9.89)
# iter : 51392 / 64000 , epochs : 146
# (TrainError) correct : 44697 / 45000, error (0.67)
# (TestError) correct : 9007 / 10000, error (9.93)
# iter : 51744 / 64000 , epochs : 147
# (TrainError) correct : 44673 / 45000, error (0.73)
# (TestError) correct : 9018 / 10000, error (9.82)
# iter : 52096 / 64000 , epochs : 148
# (TrainError) correct : 44654 / 45000, error (0.77)
# (TestError) correct : 9011 / 10000, error (9.89)
# iter : 52448 / 64000 , epochs : 149
# (TrainError) correct : 44669 / 45000, error (0.74)
# (TestError) correct : 9013 / 10000, error (9.87)
# iter : 52800 / 64000 , epochs : 150
# (TrainError) correct : 44689 / 45000, error (0.69)
# (TestError) correct : 9004 / 10000, error (9.96)
# iter : 53152 / 64000 , epochs : 151
# (TrainError) correct : 44683 / 45000, error (0.70)
# (TestError) correct : 9004 / 10000, error (9.96)
# iter : 53504 / 64000 , epochs : 152
# (TrainError) correct : 44689 / 45000, error (0.69)
# (TestError) correct : 8996 / 10000, error (10.04)
# iter : 53856 / 64000 , epochs : 153
# (TrainError) correct : 44678 / 45000, error (0.72)
# (TestError) correct : 9016 / 10000, error (9.84)
# iter : 54208 / 64000 , epochs : 154
# (TrainError) correct : 44683 / 45000, error (0.70)
# (TestError) correct : 9000 / 10000, error (10.00)
# iter : 54560 / 64000 , epochs : 155
# (TrainError) correct : 44672 / 45000, error (0.73)
# (TestError) correct : 8998 / 10000, error (10.02)
# iter : 54912 / 64000 , epochs : 156
# (TrainError) correct : 44711 / 45000, error (0.64)
# (TestError) correct : 9008 / 10000, error (9.92)
# iter : 55264 / 64000 , epochs : 157
# (TrainError) correct : 44675 / 45000, error (0.72)
# (TestError) correct : 8999 / 10000, error (10.01)
# iter : 55616 / 64000 , epochs : 158
# (TrainError) correct : 44704 / 45000, error (0.66)
# (TestError) correct : 9006 / 10000, error (9.94)
# iter : 55968 / 64000 , epochs : 159
# (TrainError) correct : 44694 / 45000, error (0.68)
# (TestError) correct : 9004 / 10000, error (9.96)
# iter : 56320 / 64000 , epochs : 160
# (TrainError) correct : 44730 / 45000, error (0.60)
# (TestError) correct : 9007 / 10000, error (9.93)
# iter : 56672 / 64000 , epochs : 161
# (TrainError) correct : 44700 / 45000, error (0.67)
# (TestError) correct : 9007 / 10000, error (9.93)
# iter : 57024 / 64000 , epochs : 162
# (TrainError) correct : 44713 / 45000, error (0.64)
# (TestError) correct : 8998 / 10000, error (10.02)
# iter : 57376 / 64000 , epochs : 163
# (TrainError) correct : 44696 / 45000, error (0.68)
# (TestError) correct : 8990 / 10000, error (10.10)
# iter : 57728 / 64000 , epochs : 164
# (TrainError) correct : 44743 / 45000, error (0.57)
# (TestError) correct : 8990 / 10000, error (10.10)
# iter : 58080 / 64000 , epochs : 165
# (TrainError) correct : 44751 / 45000, error (0.55)
# (TestError) correct : 9003 / 10000, error (9.97)
# iter : 58432 / 64000 , epochs : 166
# (TrainError) correct : 44675 / 45000, error (0.72)
# (TestError) correct : 9002 / 10000, error (9.98)
# iter : 58784 / 64000 , epochs : 167
# (TrainError) correct : 44717 / 45000, error (0.63)
# (TestError) correct : 8997 / 10000, error (10.03)
# iter : 59136 / 64000 , epochs : 168
# (TrainError) correct : 44744 / 45000, error (0.57)
# (TestError) correct : 9006 / 10000, error (9.94)
# iter : 59488 / 64000 , epochs : 169
# (TrainError) correct : 44720 / 45000, error (0.62)
# (TestError) correct : 9002 / 10000, error (9.98)
# iter : 59840 / 64000 , epochs : 170
# (TrainError) correct : 44730 / 45000, error (0.60)
# (TestError) correct : 8997 / 10000, error (10.03)
# iter : 60192 / 64000 , epochs : 171
# (TrainError) correct : 44721 / 45000, error (0.62)
# (TestError) correct : 9000 / 10000, error (10.00)
# iter : 60544 / 64000 , epochs : 172
# (TrainError) correct : 44718 / 45000, error (0.63)
# (TestError) correct : 8998 / 10000, error (10.02)
# iter : 60896 / 64000 , epochs : 173
# (TrainError) correct : 44718 / 45000, error (0.63)
# (TestError) correct : 9008 / 10000, error (9.92)
# iter : 61248 / 64000 , epochs : 174
# (TrainError) correct : 44725 / 45000, error (0.61)
# (TestError) correct : 9006 / 10000, error (9.94)
# iter : 61600 / 64000 , epochs : 175
# (TrainError) correct : 44737 / 45000, error (0.58)
# (TestError) correct : 9009 / 10000, error (9.91)
# iter : 61952 / 64000 , epochs : 176
# (TrainError) correct : 44736 / 45000, error (0.59)
# (TestError) correct : 9012 / 10000, error (9.88)
# iter : 62304 / 64000 , epochs : 177
# (TrainError) correct : 44756 / 45000, error (0.54)
# (TestError) correct : 9013 / 10000, error (9.87)
# iter : 62656 / 64000 , epochs : 178
# (TrainError) correct : 44727 / 45000, error (0.61)
# (TestError) correct : 9014 / 10000, error (9.86)
# iter : 63008 / 64000 , epochs : 179
# (TrainError) correct : 44724 / 45000, error (0.61)
# (TestError) correct : 9006 / 10000, error (9.94)
# iter : 63360 / 64000 , epochs : 180
# (TrainError) correct : 44763 / 45000, error (0.53)
# (TestError) correct : 8995 / 10000, error (10.05)
# iter : 63712 / 64000 , epochs : 181
# (TrainError) correct : 44766 / 45000, error (0.52)
# (TestError) correct : 8999 / 10000, error (10.01)
# iter : 64064 / 64000 , epochs : 182
# training finished

# %% [markdown]
# Final Results

# %%
resnet_20_train_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/resnet_20_trainerr.csv')
resnet_20_test_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/resnet_20_testerr.csv')
resnet_56_train_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/resnet_56_trainerr.csv')
resnet_56_test_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/resnet_56_testerr.csv')

plainnet_20_train_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_20_trainerr.csv')
plainnet_20_test_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_20_testerr.csv')
plainnet_56_train_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_56_trainerr.csv')
plainnet_56_test_err = pd.read_csv('drive/MyDrive/Colab_Projects/ResNet/plainnet_56_testerr.csv')

plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
plt.ylim(0,30)
plt.plot(plainnet_20_train_err,label='plainnet_20',linewidth=0.5)
plt.plot(plainnet_20_test_err,label='plainnet_20',linewidth=2.5)
plt.plot(plainnet_56_train_err,label='plainnet_56',linewidth=0.5)
plt.plot(plainnet_56_test_err,label='plainnet_56',linewidth=2.5)
plt.xlabel('epochs')
plt.ylabel('error(%)')
plt.legend()

plt.subplot(1,2,2)
plt.ylim(0,30)
plt.plot(resnet_20_train_err,label='resnet_20',linewidth=0.5)
plt.plot(resnet_20_test_err,label='resnet_20',linewidth=2.5)
plt.plot(resnet_56_train_err,label='resnet_56',linewidth=0.5)
plt.plot(resnet_56_test_err,label='resnet_56',linewidth=2.5)
plt.xlabel('epochs')
plt.ylabel('error(%)')
plt.legend()

plt.show()
